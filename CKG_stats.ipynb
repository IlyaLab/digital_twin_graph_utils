# %% [markdown]
# # Getting statistics on the CKG graph
#
# The only difference between this and the SPOKE notebook is that I'm currently running the CKG neo4j.

# %%
from neo4j import GraphDatabase
import pandas as pd

# %%
driver = GraphDatabase.driver(uri='bolt://localhost:7687')

# %%
# transactions
def get_node_sources(tx):
    result = tx.run('MATCH (n) RETURN LABELS(n), n.source, COUNT(ID(n));')
    return list(result)

def get_node_types(tx):
    return list(tx.run('MATCH (n) RETURN LABELS(n), COUNT(ID(n));'))

def get_edge_types(tx):
    return list(tx.run('MATCH ()-[e]-() RETURN TYPE(e), COUNT(e);'))

def get_edge_sources(tx):
    return list(tx.run('MATCH ()-[e]-() RETURN TYPE(e), e.source, e.sources[0], COUNT(e);'))

# %%
with driver.session() as session:
    node_sources = session.execute_read(get_node_sources)
    edge_types = session.execute_read(get_edge_types)

# %%
with driver.session() as session:
    edge_sources = session.execute_read(get_edge_sources)

# %%
node_sources_list = [x.data() for x in node_sources]
node_sources_list = [(x['LABELS(n)'][0], x['n.source'], x['COUNT(ID(n))']) for x in node_sources_list]
node_sources_table = pd.DataFrame(node_sources_list, columns=['label', 'source', 'count'])
node_sources_table = node_sources_table.sort_values('label')
node_sources_table = node_sources_table.reset_index(drop=True)

# %% [markdown]
# ## Node statistics

# %%
node_sources_table
# Out:
#                           label                     source     count
# 0           Amino_acid_sequence                    UniProt     20614
# 1             Analytical_sample                       None       172
# 2            Biological_process                       None     28642
# 3             Biological_sample                       None       170
# 4            Cellular_component                       None      4176
# 5                    Chromosome                       None        25
# 6   Clinically_relevant_variant                        CGI      6856
# 7   Clinically_relevant_variant                       None    183478
# 8                       Complex                      CORUM      2700
# 9                       Disease                       None     10791
# 10                   Experiment                       None      2829
# 11          Experimental_factor                       None      9883
# 12                         Food                      FooDB       992
# 13            Functional_region                       PFam     16169
# 14                   GWAS_study                       None      8713
# 15                         Gene                       None     42571
# 16                Known_variant                    UniProt  10630108
# 17                   Metabolite                       None    114222
# 18                 Modification                       None      1978
# 19             Modified_protein                     SIGNOR       621
# 20             Modified_protein  experimentally_identified     20786
# 21           Molecular_function                       None     11169
# 22                      Pathway                      SMPDB     48703
# 23                      Pathway                   Reactome      2516
# 24                      Peptide                       None   1001105
# 25                    Phenotype                       None     15872
# 26                      Project                       None         7
# 27                      Protein                       None    228725
# 28            Protein_structure                    Uniprot     49317
# 29                  Publication                       None   1791712
# 30                      Subject                       None       169
# 31                       Tissue                       None      5897
# 32                   Transcript                       None    280910
# 33                        Units                       None       442
# 34                         User                       None         2

# %% [markdown]
# ## Edge statistics

# %%
edge_types_list = [x.data() for x in edge_types]
edge_types_list = [(x['TYPE(e)'], x['COUNT(e)']) for x in edge_types_list]
edge_types_table = pd.DataFrame(edge_types_list, columns=['edge_type', 'count'])
edge_types_table = edge_types_table.sort_values('edge_type')
edge_types_table = edge_types_table.reset_index(drop=True)
edge_types_table
# Out:
#                            edge_type      count
# 0                            ACTS_ON    1977410
# 1               ANNOTATED_IN_PATHWAY    2407618
# 2                    ASSOCIATED_WITH   33415258
# 3                 BELONGS_TO_PROTEIN    7258116
# 4                 BELONGS_TO_SUBJECT        340
# 5            COMPILED_INTERACTS_WITH    3913224
# 6   CURATED_AFFECTS_INTERACTION_WITH      21746
# 7             CURATED_INTERACTS_WITH     595961
# 8       DETECTED_IN_PATHOLOGY_SAMPLE    3394496
# 9                   FOUND_IN_PROTEIN     408488
# 10                      HAS_ENROLLED        338
# 11                  HAS_MODIFICATION      42814
# 12                 HAS_MODIFIED_SITE      42842
# 13                        HAS_PARENT     256698
# 14   HAS_QUANTIFIED_MODIFIED_PROTEIN     448956
# 15            HAS_QUANTIFIED_PROTEIN    1595302
# 16                      HAS_SEQUENCE      41228
# 17                     HAS_STRUCTURE     391280
# 18           IS_BIOMARKER_OF_DISEASE       1030
# 19             IS_QCMARKER_IN_TISSUE        498
# 20                    IS_RESPONSIBLE         14
# 21                   IS_SUBSTRATE_OF       1988
# 22                     IS_SUBUNIT_OF      21936
# 23                        LOCATED_IN     591824
# 24                           MAPS_TO       4578
# 25          MENTIONED_IN_PUBLICATION  222218476
# 26                   PARTICIPATES_IN         14
# 27                      PUBLISHED_IN       7878
# 28                     SPLITTED_INTO        344
# 29                   STUDIES_DISEASE         14
# 30                    STUDIES_TISSUE         14
# 31                     STUDIES_TRAIT      18500
# 32                  TRANSCRIBED_INTO     516974
# 33                   TRANSLATED_INTO     748588
# 34       VARIANT_FOUND_IN_CHROMOSOME   21260216
# 35             VARIANT_FOUND_IN_GENE   21277870
# 36             VARIANT_FOUND_IN_GWAS      32256
# 37          VARIANT_FOUND_IN_PROTEIN   53614586
# 38    VARIANT_IS_CLINICALLY_RELEVANT        338

# %%
edge_types_table = edge_types_table.sort_values('count', ascending=False)
edge_types_table = edge_types_table.reset_index(drop=True)
edge_types_table
# Out:
#                            edge_type      count
# 0           MENTIONED_IN_PUBLICATION  222218476
# 1           VARIANT_FOUND_IN_PROTEIN   53614586
# 2                    ASSOCIATED_WITH   33415258
# 3              VARIANT_FOUND_IN_GENE   21277870
# 4        VARIANT_FOUND_IN_CHROMOSOME   21260216
# 5                 BELONGS_TO_PROTEIN    7258116
# 6            COMPILED_INTERACTS_WITH    3913224
# 7       DETECTED_IN_PATHOLOGY_SAMPLE    3394496
# 8               ANNOTATED_IN_PATHWAY    2407618
# 9                            ACTS_ON    1977410
# 10            HAS_QUANTIFIED_PROTEIN    1595302
# 11                   TRANSLATED_INTO     748588
# 12            CURATED_INTERACTS_WITH     595961
# 13                        LOCATED_IN     591824
# 14                  TRANSCRIBED_INTO     516974
# 15   HAS_QUANTIFIED_MODIFIED_PROTEIN     448956
# 16                  FOUND_IN_PROTEIN     408488
# 17                     HAS_STRUCTURE     391280
# 18                        HAS_PARENT     256698
# 19                 HAS_MODIFIED_SITE      42842
# 20                  HAS_MODIFICATION      42814
# 21                      HAS_SEQUENCE      41228
# 22             VARIANT_FOUND_IN_GWAS      32256
# 23                     IS_SUBUNIT_OF      21936
# 24  CURATED_AFFECTS_INTERACTION_WITH      21746
# 25                     STUDIES_TRAIT      18500
# 26                      PUBLISHED_IN       7878
# 27                           MAPS_TO       4578
# 28                   IS_SUBSTRATE_OF       1988
# 29           IS_BIOMARKER_OF_DISEASE       1030
# 30             IS_QCMARKER_IN_TISSUE        498
# 31                     SPLITTED_INTO        344
# 32                BELONGS_TO_SUBJECT        340
# 33                      HAS_ENROLLED        338
# 34    VARIANT_IS_CLINICALLY_RELEVANT        338
# 35                    STUDIES_TISSUE         14
# 36                   STUDIES_DISEASE         14
# 37                   PARTICIPATES_IN         14
# 38                    IS_RESPONSIBLE         14

# %% [markdown]
# ## Edge sources

# %%
edge_sources_list = [x.data() for x in edge_sources]
edge_sources_list = [(x['TYPE(e)'], x['e.source'], x['e.sources[0]'], x['COUNT(e)']) for x in edge_sources_list]
edge_sources_table = pd.DataFrame(edge_sources_list, columns=['edge_type', 'source', 'sources', 'count'])
edge_sources_table = edge_sources_table.sort_values('edge_type')
edge_sources_table = edge_sources_table.reset_index(drop=True)

# %%
edge_sources_table['source'] = edge_sources_table['source'].fillna(edge_sources_table['sources'])
del edge_sources_table['sources']

# %%
pd.set_option('display.max_rows', None)
edge_sources_table
# Out:
#                             edge_type  \
# 0                             ACTS_ON
# 1                ANNOTATED_IN_PATHWAY
# 2                ANNOTATED_IN_PATHWAY
# 3                     ASSOCIATED_WITH
# 4                     ASSOCIATED_WITH
# 5                     ASSOCIATED_WITH
# 6                     ASSOCIATED_WITH
# 7                     ASSOCIATED_WITH
# 8                     ASSOCIATED_WITH
# 9                     ASSOCIATED_WITH
# 10                    ASSOCIATED_WITH
# 11                    ASSOCIATED_WITH
# 12                    ASSOCIATED_WITH
# 13                    ASSOCIATED_WITH
# 14                    ASSOCIATED_WITH
# 15                    ASSOCIATED_WITH
# 16                    ASSOCIATED_WITH
# 17                    ASSOCIATED_WITH
# 18                    ASSOCIATED_WITH
# 19                    ASSOCIATED_WITH
# 20                    ASSOCIATED_WITH
# 21                    ASSOCIATED_WITH
# 22                    ASSOCIATED_WITH
# 23                    ASSOCIATED_WITH
# 24                    ASSOCIATED_WITH
# 25                    ASSOCIATED_WITH
# 26                    ASSOCIATED_WITH
# 27                    ASSOCIATED_WITH
# 28                    ASSOCIATED_WITH
# 29                    ASSOCIATED_WITH
# 30                    ASSOCIATED_WITH
# 31                    ASSOCIATED_WITH
# 32                    ASSOCIATED_WITH
# 33                    ASSOCIATED_WITH
# 34                    ASSOCIATED_WITH
# 35                    ASSOCIATED_WITH
# 36                    ASSOCIATED_WITH
# 37                    ASSOCIATED_WITH
# 38                    ASSOCIATED_WITH
# 39                    ASSOCIATED_WITH
# 40                    ASSOCIATED_WITH
# 41                    ASSOCIATED_WITH
# 42                    ASSOCIATED_WITH
# 43                    ASSOCIATED_WITH
# 44                    ASSOCIATED_WITH
# 45                    ASSOCIATED_WITH
# 46                    ASSOCIATED_WITH
# 47                    ASSOCIATED_WITH
# 48                    ASSOCIATED_WITH
# 49                    ASSOCIATED_WITH
# 50                    ASSOCIATED_WITH
# 51                    ASSOCIATED_WITH
# 52                    ASSOCIATED_WITH
# 53                    ASSOCIATED_WITH
# 54                    ASSOCIATED_WITH
# 55                    ASSOCIATED_WITH
# 56                    ASSOCIATED_WITH
# 57                    ASSOCIATED_WITH
# 58                    ASSOCIATED_WITH
# 59                    ASSOCIATED_WITH
# 60                    ASSOCIATED_WITH
# 61                    ASSOCIATED_WITH
# 62                    ASSOCIATED_WITH
# 63                 BELONGS_TO_PROTEIN
# 64                 BELONGS_TO_SUBJECT
# 65            COMPILED_INTERACTS_WITH
# 66   CURATED_AFFECTS_INTERACTION_WITH
# 67             CURATED_INTERACTS_WITH
# 68             CURATED_INTERACTS_WITH
# 69             CURATED_INTERACTS_WITH
# 70             CURATED_INTERACTS_WITH
# 71             CURATED_INTERACTS_WITH
# 72             CURATED_INTERACTS_WITH
# 73             CURATED_INTERACTS_WITH
# 74             CURATED_INTERACTS_WITH
# 75             CURATED_INTERACTS_WITH
# 76             CURATED_INTERACTS_WITH
# 77             CURATED_INTERACTS_WITH
# 78             CURATED_INTERACTS_WITH
# 79             CURATED_INTERACTS_WITH
# 80             CURATED_INTERACTS_WITH
# 81             CURATED_INTERACTS_WITH
# 82             CURATED_INTERACTS_WITH
# 83             CURATED_INTERACTS_WITH
# 84             CURATED_INTERACTS_WITH
# 85             CURATED_INTERACTS_WITH
# 86             CURATED_INTERACTS_WITH
# 87             CURATED_INTERACTS_WITH
# 88             CURATED_INTERACTS_WITH
# 89             CURATED_INTERACTS_WITH
# 90             CURATED_INTERACTS_WITH
# 91             CURATED_INTERACTS_WITH
# 92             CURATED_INTERACTS_WITH
# 93             CURATED_INTERACTS_WITH
# 94             CURATED_INTERACTS_WITH
# 95             CURATED_INTERACTS_WITH
# 96             CURATED_INTERACTS_WITH
# 97             CURATED_INTERACTS_WITH
# 98             CURATED_INTERACTS_WITH
# 99             CURATED_INTERACTS_WITH
# 100            CURATED_INTERACTS_WITH
# 101            CURATED_INTERACTS_WITH
# 102            CURATED_INTERACTS_WITH
# 103            CURATED_INTERACTS_WITH
# 104            CURATED_INTERACTS_WITH
# 105            CURATED_INTERACTS_WITH
# 106            CURATED_INTERACTS_WITH
# 107            CURATED_INTERACTS_WITH
# 108            CURATED_INTERACTS_WITH
# 109            CURATED_INTERACTS_WITH
# 110            CURATED_INTERACTS_WITH
# 111            CURATED_INTERACTS_WITH
# 112            CURATED_INTERACTS_WITH
# 113            CURATED_INTERACTS_WITH
# 114            CURATED_INTERACTS_WITH
# 115            CURATED_INTERACTS_WITH
# 116            CURATED_INTERACTS_WITH
# 117            CURATED_INTERACTS_WITH
# 118            CURATED_INTERACTS_WITH
# 119            CURATED_INTERACTS_WITH
# 120            CURATED_INTERACTS_WITH
# 121            CURATED_INTERACTS_WITH
# 122            CURATED_INTERACTS_WITH
# 123            CURATED_INTERACTS_WITH
# 124            CURATED_INTERACTS_WITH
# 125            CURATED_INTERACTS_WITH
# 126            CURATED_INTERACTS_WITH
# 127            CURATED_INTERACTS_WITH
# 128            CURATED_INTERACTS_WITH
# 129            CURATED_INTERACTS_WITH
# 130            CURATED_INTERACTS_WITH
# 131            CURATED_INTERACTS_WITH
# 132            CURATED_INTERACTS_WITH
# 133            CURATED_INTERACTS_WITH
# 134            CURATED_INTERACTS_WITH
# 135            CURATED_INTERACTS_WITH
# 136            CURATED_INTERACTS_WITH
# 137            CURATED_INTERACTS_WITH
# 138            CURATED_INTERACTS_WITH
# 139            CURATED_INTERACTS_WITH
# 140            CURATED_INTERACTS_WITH
# 141            CURATED_INTERACTS_WITH
# 142            CURATED_INTERACTS_WITH
# 143            CURATED_INTERACTS_WITH
# 144            CURATED_INTERACTS_WITH
# 145            CURATED_INTERACTS_WITH
# 146            CURATED_INTERACTS_WITH
# 147            CURATED_INTERACTS_WITH
# 148            CURATED_INTERACTS_WITH
# 149            CURATED_INTERACTS_WITH
# 150            CURATED_INTERACTS_WITH
# 151            CURATED_INTERACTS_WITH
# 152            CURATED_INTERACTS_WITH
# 153            CURATED_INTERACTS_WITH
# 154            CURATED_INTERACTS_WITH
# 155            CURATED_INTERACTS_WITH
# 156            CURATED_INTERACTS_WITH
# 157            CURATED_INTERACTS_WITH
# 158            CURATED_INTERACTS_WITH
# 159            CURATED_INTERACTS_WITH
# 160            CURATED_INTERACTS_WITH
# 161            CURATED_INTERACTS_WITH
# 162            CURATED_INTERACTS_WITH
# 163            CURATED_INTERACTS_WITH
# 164            CURATED_INTERACTS_WITH
# 165            CURATED_INTERACTS_WITH
# 166            CURATED_INTERACTS_WITH
# 167            CURATED_INTERACTS_WITH
# 168            CURATED_INTERACTS_WITH
# 169            CURATED_INTERACTS_WITH
# 170            CURATED_INTERACTS_WITH
# 171            CURATED_INTERACTS_WITH
# 172            CURATED_INTERACTS_WITH
# 173            CURATED_INTERACTS_WITH
# 174            CURATED_INTERACTS_WITH
# 175            CURATED_INTERACTS_WITH
# 176            CURATED_INTERACTS_WITH
# 177            CURATED_INTERACTS_WITH
# 178            CURATED_INTERACTS_WITH
# 179            CURATED_INTERACTS_WITH
# 180            CURATED_INTERACTS_WITH
# 181            CURATED_INTERACTS_WITH
# 182            CURATED_INTERACTS_WITH
# 183            CURATED_INTERACTS_WITH
# 184            CURATED_INTERACTS_WITH
# 185            CURATED_INTERACTS_WITH
# 186            CURATED_INTERACTS_WITH
# 187            CURATED_INTERACTS_WITH
# 188            CURATED_INTERACTS_WITH
# 189      DETECTED_IN_PATHOLOGY_SAMPLE
# 190                  FOUND_IN_PROTEIN
# 191                      HAS_ENROLLED
# 192                  HAS_MODIFICATION
# 193                  HAS_MODIFICATION
# 194                 HAS_MODIFIED_SITE
# 195                        HAS_PARENT
# 196   HAS_QUANTIFIED_MODIFIED_PROTEIN
# 197            HAS_QUANTIFIED_PROTEIN
# 198                      HAS_SEQUENCE
# 199                     HAS_STRUCTURE
# 200           IS_BIOMARKER_OF_DISEASE
# 201             IS_QCMARKER_IN_TISSUE
# 202                    IS_RESPONSIBLE
# 203                   IS_SUBSTRATE_OF
# 204                     IS_SUBUNIT_OF
# 205                        LOCATED_IN
# 206                           MAPS_TO
# 207          MENTIONED_IN_PUBLICATION
# 208          MENTIONED_IN_PUBLICATION
# 209                   PARTICIPATES_IN
# 210                      PUBLISHED_IN
# 211                     SPLITTED_INTO
# 212                   STUDIES_DISEASE
# 213                    STUDIES_TISSUE
# 214                     STUDIES_TRAIT
# 215                  TRANSCRIBED_INTO
# 216                   TRANSLATED_INTO
# 217       VARIANT_FOUND_IN_CHROMOSOME
# 218             VARIANT_FOUND_IN_GENE
# 219             VARIANT_FOUND_IN_GWAS
# 220          VARIANT_FOUND_IN_PROTEIN
# 221    VARIANT_IS_CLINICALLY_RELEVANT
# 222    VARIANT_IS_CLINICALLY_RELEVANT
#
#                                                 source      count
# 0                                               STRING    1977410
# 1                                             Reactome     117270
# 2                                                SMPDB    2290348
# 3                           DisGeNet: ORPHANET;UNIPROT         52
# 4    DisGeNet: CLINGEN;GENOMICS_ENGLAND;ORPHANET;UN...         12
# 5                                DisGeNet: CGI;UNIPROT        106
# 6                       DisGeNet: CGI;GENOMICS_ENGLAND        128
# 7     DisGeNet: CGI;CLINGEN;CTD_human;GENOMICS_ENGLAND         10
# 8           DisGeNet: CLINGEN;GENOMICS_ENGLAND;UNIPROT         22
# 9               DisGeNet: CGI;GENOMICS_ENGLAND;UNIPROT         10
# 10                              DisGeNet: CGI;ORPHANET         34
# 11                                  DisGeNet: PSYGENET       9634
# 12                 DisGeNet: CLINGEN;CTD_human;UNIPROT          4
# 13   DisGeNet: CLINGEN;CTD_human;GENOMICS_ENGLAND;U...        226
# 14   DisGeNet: CLINGEN;CTD_human;GENOMICS_ENGLAND;O...        298
# 15                    DisGeNet: CGI;CTD_human;ORPHANET         66
# 16        DisGeNet: CLINGEN;CTD_human;ORPHANET;UNIPROT          2
# 17   DisGeNet: CGI;CTD_human;GENOMICS_ENGLAND;ORPHA...          8
# 18         DisGeNet: GENOMICS_ENGLAND;ORPHANET;UNIPROT        178
# 19   DisGeNet: CGI;CTD_human;GENOMICS_ENGLAND;ORPHANET          8
# 20                     DisGeNet: CGI;CLINGEN;CTD_human          4
# 21            DisGeNet: CGI;CLINGEN;CTD_human;ORPHANET          6
# 22                           DisGeNet: CLINGEN;UNIPROT          2
# 23   DisGeNet: CGI;CLINGEN;CTD_human;GENOMICS_ENGLA...          4
# 24                 DisGeNet: GENOMICS_ENGLAND;PSYGENET          2
# 25            DisGeNet: CGI;CTD_human;ORPHANET;UNIPROT          2
# 26   DisGeNet: CGI;CLINGEN;CTD_human;GENOMICS_ENGLA...          4
# 27                                             TISSUES   13058452
# 28                                             UniProt     672516
# 29                                               CORUM       9540
# 30                                        COMPARTMENTS    7124610
# 31                                              OncoKB        186
# 32                         DisGeNet: CLINGEN;CTD_human        296
# 33                        DisGeNet: CTD_human;PSYGENET        566
# 34                DisGeNet: CLINGEN;CTD_human;ORPHANET         90
# 35                                            DISEASES    8931224
# 36                                                 CGI       8924
# 37                                    DisGeNet: BEFREE    1688338
# 38                                 DisGeNet: CTD_human      87860
# 39                             DisGeNet: CGI;CTD_human        802
# 40                          DisGeNet: GENOMICS_ENGLAND      14804
# 41                                  DisGeNet: ORPHANET       7964
# 42                        DisGeNet: CTD_human;ORPHANET       1590
# 43        DisGeNet: CTD_human;GENOMICS_ENGLAND;UNIPROT       2598
# 44         DisGeNet: CLINGEN;GENOMICS_ENGLAND;ORPHANET        248
# 45                 DisGeNet: GENOMICS_ENGLAND;ORPHANET       1306
# 46   DisGeNet: CTD_human;GENOMICS_ENGLAND;ORPHANET;...       2530
# 47                DisGeNet: CTD_human;GENOMICS_ENGLAND       3090
# 48                                   DisGeNet: CLINGEN       3392
# 49                                   DisGeNet: UNIPROT       5028
# 50       DisGeNet: CTD_human;GENOMICS_ENGLAND;ORPHANET       1548
# 51                          DisGeNet: CLINGEN;ORPHANET        358
# 52                  DisGeNet: CLINGEN;GENOMICS_ENGLAND        186
# 53                                       DisGeNet: CGI       2506
# 54            DisGeNet: CGI;CTD_human;GENOMICS_ENGLAND         54
# 55                         DisGeNet: CTD_human;UNIPROT        662
# 56                     DisGeNet: CGI;CTD_human;UNIPROT        126
# 57   DisGeNet: CLINGEN;CTD_human;GENOMICS_ENGLAND;O...        260
# 58        DisGeNet: CLINGEN;CTD_human;GENOMICS_ENGLAND        216
# 59                                                None    1771568
# 60                DisGeNet: CTD_human;ORPHANET;UNIPROT        152
# 61                  DisGeNet: GENOMICS_ENGLAND;UNIPROT        784
# 62    DisGeNet: CGI;CTD_human;GENOMICS_ENGLAND;UNIPROT         62
# 63                                             UniProt    7258116
# 64                                                None        340
# 65                                            [STRING]    3913224
# 66                                   Intact-MutationDs      21746
# 67                       [IntAct, DIP, InnateDB, MINT]          4
# 68                                [UniProt, DIP, MINT]         37
# 69                                  [IntAct, matrixdb]          6
# 70                    [UniProt, IntAct, matrixdb, DIP]          4
# 71          [Molecular Connections, IntAct, I2D, MINT]          2
# 72                               [DIP, InnateDB, MINT]          8
# 73                                   [UniProt, mbinfo]          2
# 74                                [bhf-ucl, DIP, MINT]          3
# 75     [I2D, IntAct, Molecular Connections, DIP, MINT]          2
# 76                       [IntAct, matrixdb, DIP, MINT]          2
# 77                                  [IntAct, InnateDB]         18
# 78                        [Molecular Connections, DIP]          6
# 79                                       [IntAct, I2D]         30
# 80                        [bhf-ucl, I2D, IntAct, MINT]          2
# 81                        [bhf-ucl, IntAct, DIP, MINT]          8
# 82                                     [IntAct, HPIDb]         82
# 83                                    [UniProt, HPIDb]         74
# 84                        [bhf-ucl, IntAct, I2D, MINT]          6
# 85                      [HPIDb, UniProt, IntAct, MINT]          6
# 86                               [HPIDb, IntAct, MINT]         16
# 87                            [UniProt, IntAct, HPIDb]         25
# 88                               [UniProt, DIP, HPIDb]          2
# 89                              [HPIDb, UniProt, MINT]         10
# 90          [Molecular Connections, IntAct, DIP, MINT]         10
# 91                     [Molecular Connections, IntAct]         58
# 92                                  [I2D, IntAct, DIP]          6
# 93                                       [HPIDb, MINT]         18
# 94                                        [DIP, HPIDb]          5
# 95                            [IntAct, I2D, DIP, MINT]         16
# 96                   [IntAct, I2D, DIP, MINT, bhf-ucl]          4
# 97        [Molecular Connections, IntAct, MINT, HPIDb]          2
# 98    [UniProt, Molecular Connections, IntAct, mbinfo]          2
# 99                [Molecular Connections, IntAct, DIP]          5
# 100             [Molecular Connections, IntAct, HPIDb]          6
# 101                                            [mpidb]          6
# 102                               [IntAct, DIP, HPIDb]          7
# 103                            [IntAct, matrixdb, DIP]          5
# 104                   [Molecular Connections, bhf-ucl]          2
# 105                                   [bhf-ucl, HPIDb]          1
# 106                          [UniProt, IntAct, mbinfo]          2
# 107                                    [DIP, matrixdb]          2
# 108                                   [I2D, DIP, MINT]          2
# 109                           [I2D, IntAct, DIP, MINT]          2
# 110               [Molecular Connections, I2D, IntAct]          2
# 111          [Molecular Connections, IntAct, DIP, I2D]          8
# 112                                [IntAct, I2D, MINT]         24
# 113     [Molecular Connections, bhf-ucl, IntAct, MINT]          2
# 114                       [UniProt, IntAct, I2D, MINT]          2
# 115                        [UniProt, IntAct, InnateDB]          4
# 116                           [IntAct, InnateDB, MINT]          6
# 117              [bhf-ucl, Molecular Connections, I2D]          2
# 118                 [NTNU, IntAct, I2D, MINT, bhf-ucl]          2
# 119                                [bhf-ucl, I2D, DIP]          2
# 120              [IntAct, UniProt, DIP, MINT, bhf-ucl]          1
# 121                                 [IntAct, DIP, I2D]          5
# 122           [bhf-ucl, Molecular Connections, IntAct]          2
# 123                                    [matrixdb, DIP]          2
# 124                                         [I2D, DIP]         12
# 125                      [UniProt, IntAct, DIP, HPIDb]          4
# 126                             [mbinfo, IntAct, MINT]          6
# 127                                   [UniProt, mpidb]          1
# 128                                [UniProt, InnateDB]          2
# 129                                         [matrixdb]        293
# 130                                      [IntAct, DIP]       1534
# 131                         [HPIDb, IntAct, DIP, MINT]          6
# 132                                     [mbinfo, MINT]         12
# 133      [UniProt, Molecular Connections, IntAct, DIP]          2
# 134                                          [bhf-ucl]       3332
# 135                  [UniProt, IntAct, InnateDB, MINT]          2
# 136                                     [IntAct, MINT]       5360
# 137                 [Molecular Connections, DIP, MINT]          2
# 138                                              [DIP]       9419
# 139                                              [I2D]        734
# 140                                             [MINT]      55665
# 141             [IntAct, UniProt, DIP, InnateDB, MINT]          3
# 142                                          [UniProt]      19157
# 143                                           [IntAct]     494635
# 144                                      [mbinfo, DIP]          2
# 145                           [IntAct, MINT, DIP, I2D]          2
# 146                     [Molecular Connections, HPIDb]          6
# 147                                      [MINT, HPIDb]          4
# 148                  [IntAct, I2D, UniProt, DIP, MINT]          2
# 149                                   [InnateDB, MINT]          2
# 150                            [IntAct, InnateDB, I2D]          2
# 151                [MINT, IntAct, UniProt, DIP, HPIDb]          3
# 152           [MINT, IntAct, UniProt, InnateDB, HPIDb]          2
# 153                                   [matrixdb, MINT]          3
# 154                   [UniProt, Molecular Connections]          3
# 155                              [mbinfo, IntAct, DIP]          4
# 156                             [UniProt, HPIDb, MINT]          1
# 157                                  [bhf-ucl, IntAct]         86
# 158                             [bhf-ucl, IntAct, DIP]         16
# 159                                [IntAct, DIP, MINT]        446
# 160                                        [DIP, MINT]        361
# 161                                             [NTNU]         46
# 162                                     [bhf-ucl, DIP]         20
# 163                                 [UniProt, bhf-ucl]          9
# 164                            [bhf-ucl, IntAct, MINT]         26
# 165                                [I2D, IntAct, MINT]          8
# 166                            [IntAct, DIP, InnateDB]          8
# 167              [Molecular Connections, IntAct, MINT]         17
# 168                   [UniProt, IntAct, bhf-ucl, MINT]          2
# 169                       [UniProt, IntAct, DIP, MINT]        133
# 170                               [NTNU, IntAct, MINT]          4
# 171                                      [I2D, IntAct]         40
# 172                                  [UniProt, IntAct]       1413
# 173                                         [InnateDB]        291
# 174                                     [UniProt, DIP]        151
# 175                       [Molecular Connections, I2D]          2
# 176                                        [I2D, MINT]         38
# 177                             [UniProt, IntAct, DIP]        170
# 178                                    [UniProt, MINT]        473
# 179                                   [mbinfo, IntAct]         17
# 180                                    [bhf-ucl, MINT]         32
# 181                                           [mbinfo]        209
# 182                    [mbinfo, IntAct, bhf-ucl, MINT]          2
# 183                                    [DIP, InnateDB]          7
# 184                            [Molecular Connections]        336
# 185                        [UniProt, IntAct, DIP, I2D]          2
# 186                      [Molecular Connections, MINT]         22
# 187                            [UniProt, IntAct, MINT]        350
# 188                                            [HPIDb]        427
# 189                      Human Protein Atlas pathology    3394496
# 190                                               PFam     408488
# 191                                               None        338
# 192                                               None      41572
# 193                                             SIGNOR       1242
# 194                                               None      42842
# 195                                               None     256698
# 196                                               None     448956
# 197                                               None    1595302
# 198                                            UniProt      41228
# 199                                            UniProt     391280
# 200                    Nicolai Jacob Wewer Albrechtsen       1030
# 201                                               None        498
# 202                                               None         14
# 203                                             SIGNOR       1988
# 204                                              CORUM      21936
# 205                                               None     591824
# 206                                               None       4578
# 207                                               PFam       4870
# 208                                               None  222213606
# 209                                               None         14
# 210                                               None       7878
# 211                                               None        344
# 212                                               None         14
# 213                                               None         14
# 214                                       GWAS Catalog      18500
# 215                                               None     516974
# 216                                               None     748588
# 217                                               None   21260216
# 218                                               None   21277870
# 219                                       GWAS Catalog      32256
# 220                                               None   53614586
# 221                                                CGI        294
# 222                                             OncoKB         44
