# %% [markdown]
# # Getting statistics on the SPOKE graph

# %%
from neo4j import GraphDatabase
import pandas as pd

# %%
driver = GraphDatabase.driver(uri='bolt://localhost:7687')

# %%
# transactions
def get_node_sources(tx):
    result = tx.run('MATCH (n) RETURN LABELS(n), n.source, COUNT(ID(n));')
    return list(result)

def get_node_types(tx):
    return list(tx.run('MATCH (n) RETURN LABELS(n), COUNT(ID(n));'))

def get_edge_types(tx):
    return list(tx.run('MATCH ()-[e]-() RETURN TYPE(e), COUNT(e);'))

def get_edge_sources(tx):
    return list(tx.run('MATCH ()-[e]-() RETURN TYPE(e), e.source, e.sources[0], COUNT(e);'))

# %%
with driver.session() as session:
    node_sources = session.execute_read(get_node_sources)
    edge_types = session.execute_read(get_edge_types)

# %%
with driver.session() as session:
    edge_sources = session.execute_read(get_edge_sources)

# %%
node_sources_list = [x.data() for x in node_sources]
node_sources_list = [(x['LABELS(n)'][0], x['n.source'], x['COUNT(ID(n))']) for x in node_sources_list]
node_sources_table = pd.DataFrame(node_sources_list, columns=['label', 'source', 'count'])
node_sources_table = node_sources_table.sort_values('label')
node_sources_table = node_sources_table.reset_index(drop=True)

# %% [markdown]
# ## Node statistics

# %%
node_sources_table
# Out:
#                  label               source    count
# 0              Anatomy               Uberon    14939
# 1      AnatomyCellType                 None      102
# 2    BiologicalProcess        Gene Ontology    13103
# 3             CellType                 None       54
# 4    CellularComponent        Gene Ontology     1704
# 5             Compound               ChEMBL  1961462
# 6             Compound                 kegg     5771
# 7             Compound             DrugBank      125
# 8             Compound              metacyc       42
# 9    DatabaseTimestamp                 None       56
# 10             Disease     Disease Ontology    10671
# 11                  EC                 kegg     6242
# 12                  EC              metacyc      382
# 13                Food                 None      897
# 14                Gene          Entrez Gene    19996
# 15   MolecularFunction        Gene Ontology     3356
# 16            Nutrient                 None       38
# 17            Organism        ncbi-taxonomy     8244
# 18             Pathway              metacyc     1649
# 19             Pathway                 kegg      500
# 20  PharmacologicClass  FDA via DrugCentral      534
# 21             Protein              UniProt   194579
# 22       ProteinDomain                 Pfam    18258
# 23       ProteinFamily                 Pfam      635
# 24            Reaction                 kegg     8972
# 25            Reaction              metacyc     7413
# 26            SARSCov2                 None       27
# 27          SideEffect            SIDER 4.1     6061
# 28             Symptom                 MeSH      394
# 29             Version                 None       39

# %% [markdown]
# ## Edge statistics

# %%
edge_types_list = [x.data() for x in edge_types]
edge_types_list = [(x['TYPE(e)'], x['COUNT(e)']) for x in edge_types_list]
edge_types_table = pd.DataFrame(edge_types_list, columns=['edge_type', 'count'])
edge_types_table = edge_types_table.sort_values('edge_type')
edge_types_table = edge_types_table.reset_index(drop=True)
edge_types_table
# Out:
#               edge_type    count
# 0          AFFECTS_CamG    29900
# 1        ASSOCIATES_DaG    84620
# 2             BINDS_CbP  1697038
# 3        CATALYZES_ECcR    31350
# 4           CAUSES_CcSE   238330
# 5            CAUSES_OcD     1142
# 6          CONSUMES_RcC    69248
# 7          CONTAINS_AcA    37370
# 8          CONTAINS_DcD    21914
# 9          CONTAINS_FcC    63926
# 10         CONTAINS_FcN    16290
# 11         CONTAINS_OcO    16082
# 12       CONTAINS_PWcPW     2836
# 13  CONTRAINDICATES_CcD    40342
# 14      DECREASEDIN_PdD        2
# 15    DOWNREGULATES_AdG   989778
# 16    DOWNREGULATES_CdG   944240
# 17   DOWNREGULATES_GPdG    15935
# 18   DOWNREGULATES_KGdG   502424
# 19   DOWNREGULATES_OGdG    63935
# 20          ENCODES_GeP    65984
# 21          ENCODES_OeP       54
# 22      EXPRESSES_ACTeG  1419394
# 23        EXPRESSES_AeG  3172464
# 24        INCLUDES_OiEC  8011858
# 25        INCLUDES_OiPW  4111376
# 26        INCLUDES_PCiC     5184
# 27       INCLUDES_PWiEC    19022
# 28      INCREASEDIN_PiD       96
# 29       INTERACTS_CPiP      666
# 30        INTERACTS_PiP  3296347
# 31              ISA_AiA    37370
# 32              ISA_DiD    21914
# 33              ISA_OiO    16082
# 34            ISA_PWiPW     2836
# 35             ISA_PiEC     4832
# 36          ISIN_ACTiiA      204
# 37         ISIN_ACTiiCT      204
# 38        LOCALIZES_DlA    79262
# 39       MEMBEROF_PDmPF    14328
# 40    PARTICIPATES_GpBP  1273416
# 41    PARTICIPATES_GpCC   192130
# 42    PARTICIPATES_GpMF   234402
# 43           PARTOF_ApA    18466
# 44          PARTOF_PDpP   537500
# 45         PRESENTS_DpS    48480
# 46         PRODUCES_RpC    74228
# 47        RESEMBLES_DrD   125768
# 48           TREATS_CtD    77016
# 49      UPREGULATES_AuG   171700
# 50      UPREGULATES_CuG   956286
# 51     UPREGULATES_GPuG    23654
# 52     UPREGULATES_KGuG   519484
# 53     UPREGULATES_OGuG   109769

# %%
edge_types_table = edge_types_table.sort_values('count', ascending=False)
edge_types_table = edge_types_table.reset_index(drop=True)
edge_types_table
# Out:
#               edge_type    count
# 0         INCLUDES_OiEC  8011858
# 1         INCLUDES_OiPW  4111376
# 2         INTERACTS_PiP  3296347
# 3         EXPRESSES_AeG  3172464
# 4             BINDS_CbP  1697038
# 5       EXPRESSES_ACTeG  1419394
# 6     PARTICIPATES_GpBP  1273416
# 7     DOWNREGULATES_AdG   989778
# 8       UPREGULATES_CuG   956286
# 9     DOWNREGULATES_CdG   944240
# 10          PARTOF_PDpP   537500
# 11     UPREGULATES_KGuG   519484
# 12   DOWNREGULATES_KGdG   502424
# 13          CAUSES_CcSE   238330
# 14    PARTICIPATES_GpMF   234402
# 15    PARTICIPATES_GpCC   192130
# 16      UPREGULATES_AuG   171700
# 17        RESEMBLES_DrD   125768
# 18     UPREGULATES_OGuG   109769
# 19       ASSOCIATES_DaG    84620
# 20        LOCALIZES_DlA    79262
# 21           TREATS_CtD    77016
# 22         PRODUCES_RpC    74228
# 23         CONSUMES_RcC    69248
# 24          ENCODES_GeP    65984
# 25   DOWNREGULATES_OGdG    63935
# 26         CONTAINS_FcC    63926
# 27         PRESENTS_DpS    48480
# 28  CONTRAINDICATES_CcD    40342
# 29         CONTAINS_AcA    37370
# 30              ISA_AiA    37370
# 31       CATALYZES_ECcR    31350
# 32         AFFECTS_CamG    29900
# 33     UPREGULATES_GPuG    23654
# 34              ISA_DiD    21914
# 35         CONTAINS_DcD    21914
# 36       INCLUDES_PWiEC    19022
# 37           PARTOF_ApA    18466
# 38         CONTAINS_FcN    16290
# 39         CONTAINS_OcO    16082
# 40              ISA_OiO    16082
# 41   DOWNREGULATES_GPdG    15935
# 42       MEMBEROF_PDmPF    14328
# 43        INCLUDES_PCiC     5184
# 44             ISA_PiEC     4832
# 45            ISA_PWiPW     2836
# 46       CONTAINS_PWcPW     2836
# 47           CAUSES_OcD     1142
# 48       INTERACTS_CPiP      666
# 49         ISIN_ACTiiCT      204
# 50          ISIN_ACTiiA      204
# 51      INCREASEDIN_PiD       96
# 52          ENCODES_OeP       54
# 53      DECREASEDIN_PdD        2

# %% [markdown]
# ## Edge sources

# %%
edge_sources_list = [x.data() for x in edge_sources]
edge_sources_list = [(x['TYPE(e)'], x['e.source'], x['e.sources[0]'], x['COUNT(e)']) for x in edge_sources_list]
edge_sources_table = pd.DataFrame(edge_sources_list, columns=['edge_type', 'source', 'sources', 'count'])
edge_sources_table = edge_sources_table.sort_values('edge_type')
edge_sources_table = edge_sources_table.reset_index(drop=True)

# %%
edge_sources_table['source'] = edge_sources_table['source'].fillna(edge_sources_table['sources'])
del edge_sources_table['sources']

# %%
pd.set_option('display.max_rows', None)
edge_sources_table
# Out:
#               edge_type                                 source    count
# 0          AFFECTS_CamG                               CancerRX    24924
# 1          AFFECTS_CamG                                  CIVIC     4976
# 2        ASSOCIATES_DaG                                   OMIM     6148
# 3        ASSOCIATES_DaG                                   GWAS    10124
# 4        ASSOCIATES_DaG                               DISEASES    68348
# 5             BINDS_CbP                            DrugCentral    34594
# 6             BINDS_CbP                              BindingDB  1662444
# 7        CATALYZES_ECcR                                   None    31350
# 8           CAUSES_CcSE                              SIDER 4.1   238330
# 9            CAUSES_OcD                                   None        2
# 10           CAUSES_OcD                           PathoPhenoDB     1140
# 11         CONSUMES_RcC                                   None    69248
# 12         CONTAINS_AcA                                 Uberon    37370
# 13         CONTAINS_DcD                       Disease Ontology    21914
# 14         CONTAINS_FcC                                   None    63926
# 15         CONTAINS_FcN                                   None    16290
# 16         CONTAINS_OcO                                   None    16082
# 17       CONTAINS_PWcPW                                   None     2836
# 18  CONTRAINDICATES_CcD                          [DrugCentral]    40342
# 19      DECREASEDIN_PdD                                   None        2
# 20    DOWNREGULATES_AdG                                   BGee   989778
# 21    DOWNREGULATES_CdG           CMAP/LINCS compound (trt_cp)   944240
# 22   DOWNREGULATES_GPdG            CMAP/LINCS ligand (trt_lig)    15935
# 23   DOWNREGULATES_KGdG  CMAP/LINCS knockdown (trt_xrt,trt_sh)   502424
# 24   DOWNREGULATES_OGdG     CMAP/LINCS overexpression (trt_oe)    63935
# 25          ENCODES_GeP                                UniProt    65984
# 26          ENCODES_OeP                                   None       54
# 27      EXPRESSES_ACTeG                                   None  1419394
# 28        EXPRESSES_AeG                                   BGee  3172464
# 29        INCLUDES_OiEC                                   None  8011858
# 30        INCLUDES_OiPW                                   None  4111376
# 31        INCLUDES_PCiC                            DrugCentral     5184
# 32       INCLUDES_PWiEC                                   None    19022
# 33      INCREASEDIN_PiD                                   None       96
# 34       INTERACTS_CPiP                                   None      666
# 35        INTERACTS_PiP                                 STRING  3296347
# 36              ISA_AiA                                 Uberon    37370
# 37              ISA_DiD                       Disease Ontology    21914
# 38              ISA_OiO                                   None    16082
# 39            ISA_PWiPW                                   None     2836
# 40             ISA_PiEC                                   None     4832
# 41          ISIN_ACTiiA                                   None      204
# 42         ISIN_ACTiiCT                                   None      204
# 43        LOCALIZES_DlA                            NCBI PubMed    79262
# 44       MEMBEROF_PDmPF                                   Pfam    14328
# 45    PARTICIPATES_GpBP                           NCBI gene2go  1273416
# 46    PARTICIPATES_GpCC                           NCBI gene2go   192130
# 47    PARTICIPATES_GpMF                           NCBI gene2go   234402
# 48           PARTOF_ApA                                 Uberon    18466
# 49          PARTOF_PDpP                               InterPro   537500
# 50         PRESENTS_DpS                            NCBI PubMed    48480
# 51         PRODUCES_RpC                                   None    74228
# 52        RESEMBLES_DrD                            NCBI PubMed   125768
# 53           TREATS_CtD                  [ChEMBL, DrugCentral]     2640
# 54           TREATS_CtD                          [DrugCentral]     8494
# 55           TREATS_CtD                                 ChEMBL    65882
# 56      UPREGULATES_AuG                                   BGee   171700
# 57      UPREGULATES_CuG           CMAP/LINCS compound (trt_cp)   956286
# 58     UPREGULATES_GPuG            CMAP/LINCS ligand (trt_lig)    23654
# 59     UPREGULATES_KGuG  CMAP/LINCS knockdown (trt_xrt,trt_sh)   519484
# 60     UPREGULATES_OGuG     CMAP/LINCS overexpression (trt_oe)   109769
